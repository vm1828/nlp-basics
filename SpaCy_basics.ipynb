# %% [markdown]
# # SETUP

# %% [markdown]
# ## Import

# %%
import re

from shared.corpus import Corpus
from shared.constants import *

import spacy
from spacy.matcher import Matcher
from spacy import displacy

# %% [markdown]
# # DATA

# %%
hp_corpus = Corpus(DIR_HP)
chapter1 = hp_corpus.books[0].chapters[0].text
print(chapter1[:100])
# Out:
# Mr. and Mrs. Dursley, of number four, Privet Drive, were proud to say that they were perfectly norma

# %% [markdown]
# # SPACY

# %%
nlp = spacy.load("en_core_web_lg")

# %% [markdown]
# ## Sentences

# %%
doc = nlp(chapter1) # Our doc is just Book 1 Chapter 1 !!!
sentences = list(doc.sents)
example_sentence = sentences[8]
print(example_sentence)
# Out:
# Mrs. Potter was Mrs. Dursley's sister, but they hadn't met for several years; in fact, Mrs. Dursley pretended she didn't have a sister, because her sister and her good-for-nothing husband were as unDursleyish as it was possible to be.

# %% [markdown]
# ## Named Entities

# %%
ents = example_sentence.ents

for ent in ents:
    print(ent.label)
    print(ent.label_)
    print(ent.text, end='\n\n')
# Out:
# 380
# PERSON
# Potter
#
# 380
# PERSON
# Dursley
#
# 391
# DATE
# several years
#
# 380
# PERSON
# Dursley

# %%
people_from_chapter_1 = []

for sent in sentences:
    for ent in sent.ents:
        if ent.label_ == 'PERSON' and not ent.text in people_from_chapter_1:
            people_from_chapter_1.append(ent.text)

print(sorted(people_from_chapter_1))
# Out:
# ['Albus', 'Albus Dumbledore', 'Dedalus Diggle', 'Dudley', 'Dumbledore', 'Dursley', 'Godric', 'Hagrid', 'Harold', 'Harry', 'Harry Potter', 'Harvey', 'Howard', 'James', 'James Potter', 'Jim', 'Jim McGuffin', 'Lily', 'McGonagall', 'Muggle', "Next Door's", 'Petunia', 'Pomfrey', 'Potter', 'Privet Drive', 'Ted', 'Voldemort', 'baker']

# %% [markdown]
# ## Parts of Speech

# %%
for token in example_sentence[-20:]:
    print(f"{token.text:<15} {token.pos:<5} {token.pos_:<10}")
# Out:
# her             95    PRON
# sister          92    NOUN
# and             89    CCONJ
# her             95    PRON
# good            84    ADJ
# -               97    PUNCT
# for             85    ADP
# -               97    PUNCT
# nothing         95    PRON
# husband         92    NOUN
# were            87    AUX
# as              86    ADV
# unDursleyish    84    ADJ
# as              98    SCONJ
# it              95    PRON
# was             87    AUX
# possible        84    ADJ
# to              94    PART
# be              87    AUX
# .               97    PUNCT

# %%
print(example_sentence)
print('Nouns: ', [token for token in example_sentence if token.pos_ == 'NOUN'])
print('Noun chunks: ', list(example_sentence.noun_chunks))
# Out:
# Mrs. Potter was Mrs. Dursley's sister, but they hadn't met for several years; in fact, Mrs. Dursley pretended she didn't have a sister, because her sister and her good-for-nothing husband were as unDursleyish as it was possible to be.
# Nouns:  [sister, years, fact, sister, sister, husband]
# Noun chunks:  [Mrs. Potter, Mrs. Dursley's sister, they, several years, fact, Mrs. Dursley, she, a sister, her sister, nothing, it]

# %%
Dursleys_chunks = [chunk.text for chunk in doc.noun_chunks if 'Dursley' in chunk.text]
print(set(Dursleys_chunks))
# Out:
# {'Mrs. Dursley', "Mrs. Dursley's scream", "Mrs. Dursley's sister", 'Mr. Dursley', 'Mr. and Mrs. Dursley', 'The Dursleys', "the Dursleys' house", "the Dursleys' dark living-room window"}

# %% [markdown]
# ### SpaCy Matcher

# %%
# Prepare patterns
pron_verb_adv = [{"POS": "PRON"}, {"POS": "VERB"}, {"POS": "ADV"}]
adv_adj_noun = [{"POS": "ADV"}, {"POS": "ADJ"},{"POS": "NOUN"}]
patterns = [pron_verb_adv, adv_adj_noun]

# Create Matcher
matcher = Matcher(nlp.vocab)
matcher.add("ADV_VERB", patterns)

# Match patterns
matches = matcher(doc)
phrases = [doc[start:end] for _, start, end in matches]

print(phrases[:5])
# Out:
# [very large mustache, she spent so, most boring tie, It stared back, strangely dressed people]

# %% [markdown]
# ### Lemmatization

# %%
print(example_sentence)
for token in example_sentence:
    if token.text != token.lemma_:
        print(f"{token.text:<15} {token.lemma_:<15}")
# Out:
# Mrs. Potter was Mrs. Dursley's sister, but they hadn't met for several years; in fact, Mrs. Dursley pretended she didn't have a sister, because her sister and her good-for-nothing husband were as unDursleyish as it was possible to be.
# was             be
# had             have
# n't             not
# met             meet
# years           year
# pretended       pretend
# did             do
# n't             not
# were            be
# unDursleyish    undursleyish
# was             be

# %% [markdown]
# ## Displacy

# %%
# html = displacy.serve(example_sentence, style="dep")
# html = displacy.render(example_sentence, style="dep")

def visualize(doc, style, distance=70):
    ents_colors = {
        "PERSON": "linear-gradient(90deg, red, yellow)", 
        "ORG": "blue"
    }
    displacy.render(
        doc,
        style=style,
        jupyter=True,
        options={
            "compact": True,       # tighter layout
            "color": "#FFFF00",
            "bg": "#111111",
            "font": "Source Sans Pro",
            "distance": 70,        # space between words
            "page_width": 500,
            "ents": ["PERSON", "ORG"],
            "colors": ents_colors
        }
    )

# %%
visualize(example_sentence, "dep")
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="b0da06b6ddb443eb87b29880fae6c90f-0" class="displacy" width="3130" height="382.0" direction="ltr" style="max-width: none; height: 382.0px; color: #FFFF00; background: #111111; font-family: Source Sans Pro; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="292.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">Mrs.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="292.0">
#     <tspan class="displacy-word" fill="currentColor" x="120">Potter</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="120">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="292.0">
#     <tspan class="displacy-word" fill="currentColor" x="190">was</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="190">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="292.0">
#     <tspan class="displacy-word" fill="currentColor" x="260">Mrs.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="260">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="292.0">
#     <tspan class="displacy-word" fill="currentColor" x="330">Dursley</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="330">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="292.0">
#     <tspan class="displacy-word" fill="currentColor" x="400">'s</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="400">PART</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="292.0">
#     <tspan class="displacy-word" fill="currentColor" x="470">sister,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="470">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="292.0">
#     <tspan class="displacy-word" fill="currentColor" x="540">but</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="540">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="292.0">
#     <tspan class="displacy-word" fill="currentColor" x="610">they</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="610">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="292.0">
#     <tspan class="displacy-word" fill="currentColor" x="680">had</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="680">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="292.0">
#     <tspan class="displacy-word" fill="currentColor" x="750">n't</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750">PART</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="292.0">
#     <tspan class="displacy-word" fill="currentColor" x="820">met</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="820">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="292.0">
#     <tspan class="displacy-word" fill="currentColor" x="890">for</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="890">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="292.0">
#     <tspan class="displacy-word" fill="currentColor" x="960">several</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="960">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="292.0">
#     <tspan class="displacy-word" fill="currentColor" x="1030">years;</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1030">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="292.0">
#     <tspan class="displacy-word" fill="currentColor" x="1100">in</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1100">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="292.0">
#     <tspan class="displacy-word" fill="currentColor" x="1170">fact,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1170">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="292.0">
#     <tspan class="displacy-word" fill="currentColor" x="1240">Mrs.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1240">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="292.0">
#     <tspan class="displacy-word" fill="currentColor" x="1310">Dursley</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1310">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="292.0">
#     <tspan class="displacy-word" fill="currentColor" x="1380">pretended</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1380">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="292.0">
#     <tspan class="displacy-word" fill="currentColor" x="1450">she</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1450">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="292.0">
#     <tspan class="displacy-word" fill="currentColor" x="1520">did</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1520">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="292.0">
#     <tspan class="displacy-word" fill="currentColor" x="1590">n't</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1590">PART</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="292.0">
#     <tspan class="displacy-word" fill="currentColor" x="1660">have</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1660">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="292.0">
#     <tspan class="displacy-word" fill="currentColor" x="1730">a</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1730">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="292.0">
#     <tspan class="displacy-word" fill="currentColor" x="1800">sister,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1800">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="292.0">
#     <tspan class="displacy-word" fill="currentColor" x="1870">because</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1870">SCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="292.0">
#     <tspan class="displacy-word" fill="currentColor" x="1940">her</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1940">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="292.0">
#     <tspan class="displacy-word" fill="currentColor" x="2010">sister</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2010">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="292.0">
#     <tspan class="displacy-word" fill="currentColor" x="2080">and</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2080">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="292.0">
#     <tspan class="displacy-word" fill="currentColor" x="2150">her</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2150"

# %%
visualize(example_sentence, "ent")
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">Mrs.
# <mark class="entity" style="background: linear-gradient(90deg, red, yellow); padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Potter
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  was Mrs.
# <mark class="entity" style="background: linear-gradient(90deg, red, yellow); padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Dursley
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# 's sister, but they hadn't met for several years; in fact, Mrs.
# <mark class="entity" style="background: linear-gradient(90deg, red, yellow); padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Dursley
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  pretended she didn't have a sister, because her sister and her good-for-nothing husband were as unDursleyish as it was possible to be. </div></span>
